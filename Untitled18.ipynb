# %%
# !pip install pymongo

from pymongo import MongoClient

client = MongoClient("mongodb+srv://northstaradmin:Northstar121121@cluster0.wxuowzu.mongodb.net/?appName=Cluster0")

db = client["northstar_database"]

print("MongoDB Connected Successfully")
# Out:
# Requirement already satisfied: pymongo in /usr/local/lib/python3.12/dist-packages (4.17.0)
# Requirement already satisfied: dnspython<3.0.0,>=2.6.1 in /usr/local/lib/python3.12/dist-packages (from pymongo) (2.8.0)
# MongoDB Connected Successfully

# %%
import os

print(os.listdir('/content'))
# Out:
# ['.config', 'clean_orders.csv', 'clean_customers.csv', 'clean_incidents.csv', 'clean_app_events.csv', 'clean_deliveries.csv', 'clean_hubs.csv', 'clean_complaints.csv', 'clean_drivers.csv', 'clean_vehicles.csv', 'sample_data']

# %%
import pandas as pd

app_events = pd.read_csv('/content/clean_app_events.csv')

complaints = pd.read_csv('/content/clean_complaints.csv')

customers = pd.read_csv('/content/clean_customers.csv')

deliveries = pd.read_csv('/content/clean_deliveries.csv')

drivers = pd.read_csv('/content/clean_drivers.csv')

hubs = pd.read_csv('/content/clean_hubs.csv')

incidents = pd.read_csv('/content/clean_incidents.csv')

orders = pd.read_csv('/content/clean_orders.csv')

vehicles = pd.read_csv('/content/clean_vehicles.csv')

print("All datasets loaded successfully")
# Out:
# All datasets loaded successfully

# %%
app_events_collection = db["app_events"]

complaints_collection = db["complaints"]

customers_collection = db["customers"]

deliveries_collection = db["deliveries"]

drivers_collection = db["drivers"]

hubs_collection = db["hubs"]

incidents_collection = db["incidents"]

orders_collection = db["orders"]

vehicles_collection = db["vehicles"]

print("All collections created successfully")
# Out:
# All collections created successfully

# %%
app_events_data = app_events.to_dict(orient='records')

complaints_data = complaints.to_dict(orient='records')

customers_data = customers.to_dict(orient='records')

deliveries_data = deliveries.to_dict(orient='records')

drivers_data = drivers.to_dict(orient='records')

hubs_data = hubs.to_dict(orient='records')

incidents_data = incidents.to_dict(orient='records')

orders_data = orders.to_dict(orient='records')

vehicles_data = vehicles.to_dict(orient='records')

print("All datasets converted to MongoDB documents")
# Out:
# All datasets converted to MongoDB documents

# %%
from pymongo import MongoClient

client = MongoClient("mongodb+srv://northstaradmin:Northstar121121@cluster0.wxuowzu.mongodb.net/?retryWrites=true&w=majority")

db = client["northstar_database"]

print("MongoDB Connected Successfully")
# Out:
# MongoDB Connected Successfully

# %%
print(client.list_database_names())
# Out:
# ['northstar_database', 'admin', 'local']

# %%
app_events_collection.insert_many(app_events_data)

complaints_collection.insert_many(complaints_data)

customers_collection.insert_many(customers_data)

deliveries_collection.insert_many(deliveries_data)

drivers_collection.insert_many(drivers_data)

hubs_collection.insert_many(hubs_data)

incidents_collection.insert_many(incidents_data)

orders_collection.insert_many(orders_data)

vehicles_collection.insert_many(vehicles_data)

print("All datasets inserted successfully into MongoDB Atlas")
# Out:
# All datasets inserted successfully into MongoDB Atlas

# %%
for data in orders_collection.find().limit(5):
    print(data)
# Out:
# {'_id': ObjectId('69fd9be28366bff6ed18a8de'), 'order_id': 'O00014', 'customer_id': 'C0318', 'service_type': 'Passenger', 'order_created_at': '2024-08-25 10:12:00', 'promised_window_hours': 6, 'pickup_zone': 'Ctr', 'dropoff_zone': 'Ctr', 'priority_level': 'Low', 'order_value': 90.96, 'booking_channel': 'Phone', 'special_handling_flag': 0}
# {'_id': ObjectId('69fd9be28366bff6ed18a8f4'), 'order_id': 'O00036', 'customer_id': 'C0126', 'service_type': 'Parcel', 'order_created_at': '2024-11-06 04:24:00', 'promised_window_hours': 4, 'pickup_zone': 'Riverside', 'dropoff_zone': 'North', 'priority_level': 'Medium', 'order_value': 73.14, 'booking_channel': 'App', 'special_handling_flag': 0}
# {'_id': ObjectId('69fd9be28366bff6ed18a8fe'), 'order_id': 'O00046', 'customer_id': 'C0538', 'service_type': 'Parcel', 'order_created_at': '2025-12-13 01:15:00', 'promised_window_hours': 4, 'pickup_zone': 'NORTH', 'dropoff_zone': 'CENTRAL', 'priority_level': 'High', 'order_value': 85.48, 'booking_channel': 'App', 'special_handling_flag': 0}
# {'_id': ObjectId('69fd9be28366bff6ed18a911'), 'order_id': 'O00065', 'customer_id': 'C0285', 'service_type': 'Parcel', 'order_created_at': '2024-09-23 07:03:00', 'promised_window_hours': 4, 'pickup_zone': 'SOUTH', 'dropoff_zone': 'West', 'priority_level': 'High', 'order_value': 61.59, 'booking_channel': 'App', 'special_handling_flag': 0}
# {'_id': ObjectId('69fd9be28366bff6ed18a91c'), 'order_id': 'O00076', 'customer_id': 'C0075', 'service_type': 'Retail', 'order_created_at': '2025-12-25 04:37:00', 'promised_window_hours': 4, 'pickup_zone': 'Ctr', 'dropoff_zone': 'Riverside', 'priority_level': 'Low', 'order_value': 100.62, 'booking_channel': 'Phone', 'special_handling_flag': 0}

# %%
for data in orders_collection.find(
    {},
    {"order_id": 1, "customer_id": 1, "service_type": 1, "_id": 0}
).limit(5):

    print(data)
# Out:
# {'order_id': 'O00014', 'customer_id': 'C0318', 'service_type': 'Passenger'}
# {'order_id': 'O00036', 'customer_id': 'C0126', 'service_type': 'Parcel'}
# {'order_id': 'O00046', 'customer_id': 'C0538', 'service_type': 'Parcel'}
# {'order_id': 'O00065', 'customer_id': 'C0285', 'service_type': 'Parcel'}
# {'order_id': 'O00076', 'customer_id': 'C0075', 'service_type': 'Retail'}

# %%
high_value_orders = orders_collection.find(
    {
        "order_value": {
            "$gt": 100
        }
    }
)

for data in high_value_orders.limit(5):
    print(data)
# Out:
# {'_id': ObjectId('69fd9be28366bff6ed18a91c'), 'order_id': 'O00076', 'customer_id': 'C0075', 'service_type': 'Retail', 'order_created_at': '2025-12-25 04:37:00', 'promised_window_hours': 4, 'pickup_zone': 'Ctr', 'dropoff_zone': 'Riverside', 'priority_level': 'Low', 'order_value': 100.62, 'booking_channel': 'Phone', 'special_handling_flag': 0}
# {'_id': ObjectId('69fd9be28366bff6ed18a923'), 'order_id': 'O00083', 'customer_id': 'C0215', 'service_type': 'Medical', 'order_created_at': '2024-10-23 00:23:00', 'promised_window_hours': 2, 'pickup_zone': 'Airport', 'dropoff_zone': 'SOUTH', 'priority_level': 'Low', 'order_value': 127.88, 'booking_channel': 'App', 'special_handling_flag': 0}
# {'_id': ObjectId('69fd9be28366bff6ed18a966'), 'order_id': 'O00150', 'customer_id': 'C0246', 'service_type': 'Business', 'order_created_at': '2025-01-15 17:37:00', 'promised_window_hours': 6, 'pickup_zone': 'West', 'dropoff_zone': 'RiverSide', 'priority_level': 'Medium', 'order_value': 136.44, 'booking_channel': 'Web', 'special_handling_flag': 0}
# {'_id': ObjectId('69fd9be28366bff6ed18a968'), 'order_id': 'O00152', 'customer_id': 'C0239', 'service_type': 'Retail', 'order_created_at': '2024-09-03 18:28:00', 'promised_window_hours': 24, 'pickup_zone': 'EAST', 'dropoff_zone': 'North', 'priority_level': 'Medium', 'order_value': 139.65, 'booking_channel': 'Web', 'special_handling_flag': 0}
# {'_id': ObjectId('69fd9be28366bff6ed18a9d8'), 'order_id': 'O00264', 'customer_id': 'C0633', 'service_type': 'Business', 'order_created_at': '2025-08-12 10:46:00', 'promised_window_hours': 6, 'pickup_zone': 'EAST', 'dropoff_zone': 'AIRPORT', 'priority_level': 'Medium', 'order_value': 113.96, 'booking_channel': 'App', 'special_handling_flag': 1}

# %%
for data in orders_collection.find().sort("order_value", -1).limit(5):

    print(data)
# Out:
# {'_id': ObjectId('69fda38d8366bff6ed18cef1'), 'order_id': 'O00980', 'customer_id': 'C0545', 'service_type': 'Parcel', 'order_created_at': '2024-11-25 23:02:00', 'promised_window_hours': 4, 'pickup_zone': 'West', 'dropoff_zone': 'Riverside', 'priority_level': 'Medium', 'order_value': 510.06, 'booking_channel': 'App', 'special_handling_flag': 0}
# {'_id': ObjectId('69fd9c168366bff6ed18bdca'), 'order_id': 'O00980', 'customer_id': 'C0545', 'service_type': 'Parcel', 'order_created_at': '2024-11-25 23:02:00', 'promised_window_hours': 4, 'pickup_zone': 'West', 'dropoff_zone': 'Riverside', 'priority_level': 'Medium', 'order_value': 510.06, 'booking_channel': 'App', 'special_handling_flag': 0}
# {'_id': ObjectId('69fdace78366bff6ed18f13f'), 'order_id': 'O00980', 'customer_id': 'C0545', 'service_type': 'Parcel', 'order_created_at': '2024-11-25 23:02:00', 'promised_window_hours': 4, 'pickup_zone': 'West', 'dropoff_zone': 'Riverside', 'priority_level': 'Medium', 'order_value': 510.06, 'booking_channel': 'App', 'special_handling_flag': 0}
# {'_id': ObjectId('69fdaa9e8366bff6ed18e018'), 'order_id': 'O00980', 'customer_id': 'C0545', 'service_type': 'Parcel', 'order_created_at': '2024-11-25 23:02:00', 'promised_window_hours': 4, 'pickup_zone': 'West', 'dropoff_zone': 'Riverside', 'priority_level': 'Medium', 'order_value': 510.06, 'booking_channel': 'App', 'special_handling_flag': 0}
# {'_id': ObjectId('69fd9be28366bff6ed18aca4'), 'order_id': 'O00980', 'customer_id': 'C0545', 'service_type': 'Parcel', 'order_created_at': '2024-11-25 23:02:00', 'promised_window_hours': 4, 'pickup_zone': 'West', 'dropoff_zone': 'Riverside', 'priority_level': 'Medium', 'order_value': 510.06, 'booking_channel': 'App', 'special_handling_flag': 0}

# %%
new_order = {
    "order_id": "O5000",
    "customer_id": "C100",
    "service_type": "Priority Delivery"
}

orders_collection.insert_one(new_order)

print("New order inserted successfully")
# Out:
# New order inserted successfully

# %%
orders_collection.update_one(
    {"order_id": "O5000"},
    {"$set": {"service_type": "Express Delivery"}}
)

print("Order updated successfully")
# Out:
# Order updated successfully

# %%
orders_collection.delete_one(
    {"order_id": "O5000"}
)

print("Order deleted successfully")
# Out:
# Order deleted successfully

# %%
pipeline = [
    {
        "$group": {
            "_id": "$service_type",
            "total_orders": {"$sum": 1}
        }
    }
]

result = orders_collection.aggregate(pipeline)

for data in result:
    print(data)
# Out:
# {'_id': 'Parcel', 'total_orders': 2156}
# {'_id': 'Medical', 'total_orders': 973}
# {'_id': 'Business', 'total_orders': 1155}
# {'_id': 'Retail', 'total_orders': 2079}
# {'_id': 'Passenger', 'total_orders': 2387}

# %%
orders_collection.create_index("customer_id")

print("Index created successfully")
# Out:
# Index created successfully

# %%
print(orders_collection.index_information())
# Out:
# {'_id_': {'v': 2, 'key': [('_id', 1)]}, 'customer_id_1': {'v': 2, 'key': [('customer_id', 1)]}}

# %%
print("MongoDB Atlas Implementation Completed Successfully")
# Out:
# MongoDB Atlas Implementation Completed Successfully

# %%
pipeline = [
    {
        "$group": {
            "_id": "$complaint_type",
            "total_complaints": {"$sum": 1}
        }
    }
]

result = complaints_collection.aggregate(pipeline)

for data in result:
    print(data)
# Out:
# {'_id': 'AppIssue', 'total_complaints': 371}
# {'_id': 'Delay', 'total_complaints': 707}
# {'_id': 'MissedPickup', 'total_complaints': 448}
# {'_id': 'Damage', 'total_complaints': 105}
# {'_id': 'SupportExperience', 'total_complaints': 140}
# {'_id': 'DriverBehaviour', 'total_complaints': 357}
# {'_id': 'Billing', 'total_complaints': 112}

# %%
pipeline = [
    {
        "$group": {
            "_id": "$incident_type",
            "total_incidents": {"$sum": 1}
        }
    }
]

result = incidents_collection.aggregate(pipeline)

for data in result:
    print(data)
# Out:
# {'_id': 'AppSyncError', 'total_incidents': 217}
# {'_id': 'VehicleFault', 'total_incidents': 259}
# {'_id': 'TemperatureIssue', 'total_incidents': 203}
# {'_id': 'BatteryAlert', 'total_incidents': 252}
# {'_id': 'RouteDeviation', 'total_incidents': 301}
# {'_id': 'CustomerNoShow', 'total_incidents': 308}
# {'_id': 'SafetyNearMiss', 'total_incidents': 98}
# {'_id': 'ProofMissing', 'total_incidents': 322}

# %%
pipeline = [
    {
        "$group": {
            "_id": "$vehicle_type",
            "total_vehicles": {"$sum": 1}
        }
    }
]

result = vehicles_collection.aggregate(pipeline)

for data in result:
    print(data)
# Out:
# {'_id': 'CargoVan', 'total_vehicles': 210}
# {'_id': 'EV', 'total_vehicles': 301}
# {'_id': 'Diesel', 'total_vehicles': 133}
# {'_id': 'Hybrid', 'total_vehicles': 196}

# %%
orders_collection.create_index("customer_id")

print("Index created successfully")
# Out:
# Index created successfully

# %%
print(orders_collection.index_information())
# Out:
# {'_id_': {'v': 2, 'key': [('_id', 1)]}, 'customer_id_1': {'v': 2, 'key': [('customer_id', 1)]}}

# %%
print("MongoDB Atlas Implementation Completed Successfully")
# Out:
# MongoDB Atlas Implementation Completed Successfully
